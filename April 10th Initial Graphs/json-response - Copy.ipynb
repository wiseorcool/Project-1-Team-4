# %%
import pandas as pd
import json
import requests

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
url = "https://data.lacity.org/resource/2nrs-mtv8.json?"
limit = "&$limit=1000000"
token = "$$app_token=2chCzz50gH6DpOapebwdtsXcQ"
# params = {"token": "$$app_token=2chCzz50gH6DpOapebwdtsXcQ",
#           "limit": "&$limit=10000"
# }
response = requests.get(url,limit).json()

# %%
len(response)
# Out:
# 925720

# %%
response
# Out:
# [{'dr_no': '190326475',
#   'date_rptd': '2020-03-01T00:00:00.000',
#   'date_occ': '2020-03-01T00:00:00.000',
#   'time_occ': '2130',
#   'area': '07',
#   'area_name': 'Wilshire',
#   'rpt_dist_no': '0784',
#   'part_1_2': '1',
#   'crm_cd': '510',
#   'crm_cd_desc': 'VEHICLE - STOLEN',
#   'vict_age': '0',
#   'vict_sex': 'M',
#   'vict_descent': 'O',
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'status': 'AA',
#   'status_desc': 'Adult Arrest',
#   'crm_cd_1': '510',
#   'crm_cd_2': '998',
#   'location': '1900 S  LONGWOOD                     AV',
#   'lat': '34.0375',
#   'lon': '-118.3506'},
#  {'dr_no': '200106753',
#   'date_rptd': '2020-02-09T00:00:00.000',
#   'date_occ': '2020-02-08T00:00:00.000',
#   'time_occ': '1800',
#   'area': '01',
#   'area_name': 'Central',
#   'rpt_dist_no': '0182',
#   'part_1_2': '1',
#   'crm_cd': '330',
#   'crm_cd_desc': 'BURGLARY FROM VEHICLE',
#   'mocodes': '1822 1402 0344',
#   'vict_age': '47',
#   'vict_sex': 'M',
#   'vict_descent': 'O',
#   'premis_cd': '128',
#   'premis_desc': 'BUS STOP/LAYOVER (ALSO QUERY 124)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '330',
#   'crm_cd_2': '998',
#   'location': '1000 S  FLOWER                       ST',
#   'lat': '34.0444',
#   'lon': '-118.2628'},
#  {'dr_no': '200320258',
#   'date_rptd': '2020-11-11T00:00:00.000',
#   'date_occ': '2020-11-04T00:00:00.000',
#   'time_occ': '1700',
#   'area': '03',
#   'area_name': 'Southwest',
#   'rpt_dist_no': '0356',
#   'part_1_2': '1',
#   'crm_cd': '480',
#   'crm_cd_desc': 'BIKE - STOLEN',
#   'mocodes': '0344 1251',
#   'vict_age': '19',
#   'vict_sex': 'X',
#   'vict_descent': 'X',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '480',
#   'location': '1400 W  37TH                         ST',
#   'lat': '34.021',
#   'lon': '-118.3002'},
#  {'dr_no': '200907217',
#   'date_rptd': '2023-05-10T00:00:00.000',
#   'date_occ': '2020-03-10T00:00:00.000',
#   'time_occ': '2037',
#   'area': '09',
#   'area_name': 'Van Nuys',
#   'rpt_dist_no': '0964',
#   'part_1_2': '1',
#   'crm_cd': '343',
#   'crm_cd_desc': 'SHOPLIFTING-GRAND THEFT ($950.01 & OVER)',
#   'mocodes': '0325 1501',
#   'vict_age': '19',
#   'vict_sex': 'M',
#   'vict_descent': 'O',
#   'premis_cd': '405',
#   'premis_desc': 'CLOTHING STORE',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '343',
#   'location': '14000    RIVERSIDE                    DR',
#   'lat': '34.1576',
#   'lon': '-118.4387'},
#  {'dr_no': '220614831',
#   'date_rptd': '2022-08-18T00:00:00.000',
#   'date_occ': '2020-08-17T00:00:00.000',
#   'time_occ': '1200',
#   'area': '06',
#   'area_name': 'Hollywood',
#   'rpt_dist_no': '0666',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '1822 1501 0930 2004',
#   'vict_age': '28',
#   'vict_sex': 'M',
#   'vict_descent': 'H',
#   'premis_cd': '102',
#   'premis_desc': 'SIDEWALK',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '1900    TRANSIENT',
#   'lat': '34.0944',
#   'lon': '-118.3277'},
#  {'dr_no': '231808869',
#   'date_rptd': '2023-04-04T00:00:00.000',
#   'date_occ': '2020-12-01T00:00:00.000',
#   'time_occ': '2300',
#   'area': '18',
#   'area_name': 'Southeast',
#   'rpt_dist_no': '1826',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '1822 0100 0930 0929',
#   'vict_age': '41',
#   'vict_sex': 'M',
#   'vict_descent': 'H',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '9900    COMPTON                      AV',
#   'lat': '33.9467',
#   'lon': '-118.2463'},
#  {'dr_no': '230110144',
#   'date_rptd': '2023-04-04T00:00:00.000',
#   'date_occ': '2020-07-03T00:00:00.000',
#   'time_occ': '0900',
#   'area': '01',
#   'area_name': 'Central',
#   'rpt_dist_no': '0182',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0930 0929',
#   'vict_age': '25',
#   'vict_sex': 'M',
#   'vict_descent': 'H',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '1100 S  GRAND                        AV',
#   'lat': '34.0415',
#   'lon': '-118.262'},
#  {'dr_no': '220314085',
#   'date_rptd': '2022-07-22T00:00:00.000',
#   'date_occ': '2020-05-12T00:00:00.000',
#   'time_occ': '1110',
#   'area': '03',
#   'area_name': 'Southwest',
#   'rpt_dist_no': '0303',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0100',
#   'vict_age': '27',
#   'vict_sex': 'F',
#   'vict_descent': 'B',
#   'premis_cd': '248',
#   'premis_desc': 'CELL PHONE STORE',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '2500 S  SYCAMORE                     AV',
#   'lat': '34.0335',
#   'lon': '-118.3537'},
#  {'dr_no': '231309864',
#   'date_rptd': '2023-04-28T00:00:00.000',
#   'date_occ': '2020-12-09T00:00:00.000',
#   'time_occ': '1400',
#   'area': '13',
#   'area_name': 'Newton',
#   'rpt_dist_no': '1375',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0100',
#   'vict_age': '24',
#   'vict_sex': 'F',
#   'vict_descent': 'B',
#   'premis_cd': '750',
#   'premis_desc': 'CYBERSPACE',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '1300 E  57TH                         ST',
#   'lat': '33.9911',
#   'lon': '-118.2521'},
#  {'dr_no': '211904005',
#   'date_rptd': '2020-12-31T00:00:00.000',
#   'date_occ': '2020-12-31T00:00:00.000',
#   'time_occ': '1220',
#   'area': '19',
#   'area_name': 'Mission',
#   'rpt_dist_no': '1974',
#   'part_1_2': '2',
#   'crm_cd': '624',
#   'crm_cd_desc': 'BATTERY - SIMPLE ASSAULT',
#   'mocodes': '0416',
#   'vict_age': '26',
#   'vict_sex': 'M',
#   'vict_descent': 'H',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'weapon_used_cd': '400',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '624',
#   'location': '9000    CEDROS                       AV',
#   'lat': '34.2336',
#   'lon': '-118.4535'},
#  {'dr_no': '221804943',
#   'date_rptd': '2022-01-21T00:00:00.000',
#   'date_occ': '2020-07-01T00:00:00.000',
#   'time_occ': '1335',
#   'area': '18',
#   'area_name': 'Southeast',
#   'rpt_dist_no': '1822',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '1822 0930',
#   'vict_age': '26',
#   'vict_sex': 'M',
#   'vict_descent': 'B',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '100 W  COLDEN                       AV',
#   'lat': '33.9492',
#   'lon': '-118.2739'},
#  {'dr_no': '221908151',
#   'date_rptd': '2022-04-12T00:00:00.000',
#   'date_occ': '2020-10-01T00:00:00.000',
#   'time_occ': '0001',
#   'area': '19',
#   'area_name': 'Mission',
#   'rpt_dist_no': '1988',
#   'part_1_2': '1',
#   'crm_cd': '821',
#   'crm_cd_desc': 'SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO ANUS OTH',
#   'mocodes': '0913 2024 1817 0360 1258 0507',
#   'vict_age': '8',
#   'vict_sex': 'F',
#   'vict_descent': 'H',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'weapon_used_cd': '400',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '812',
#   'crm_cd_2': '821',
#   'location': '13400    RANGOON                      ST',
#   'lat': '34.2285',
#   'lon': '-118.4258'},
#  {'dr_no': '230204214',
#   'date_rptd': '2023-01-05T00:00:00.000',
#   'date_occ': '2020-02-01T00:00:00.000',
#   'time_occ': '0800',
#   'area': '02',
#   'area_name': 'Rampart',
#   'rpt_dist_no': '0201',
#   'part_1_2': '2',
#   'crm_cd': '812',
#   'crm_cd_desc': 'CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 YRS OLDER)',
#   'mocodes': '1251 1258 0913 0400 0500 0522 1817',
#   'vict_age': '7',
#   'vict_sex': 'F',
#   'vict_descent': 'W',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'weapon_used_cd': '400',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '812',
#   'crm_cd_2': '860',
#   'location': '900 N  MARIPOSA                     AV',
#   'lat': '34.0868',
#   'lon': '-118.2991'},
#  {'dr_no': '221008844',
#   'date_rptd': '2022-05-06T00:00:00.000',
#   'date_occ': '2020-11-01T00:00:00.000',
#   'time_occ': '0130',
#   'area': '10',
#   'area_name': 'West Valley',
#   'rpt_dist_no': '1029',
#   'part_1_2': '1',
#   'crm_cd': '510',
#   'crm_cd_desc': 'VEHICLE - STOLEN',
#   'vict_age': '0',
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '510',
#   'location': 'VALJEAN                      ST',
#   'cross_street': 'VANOWEN                      AV',
#   'lat': '34.1939',
#   'lon': '-118.4859'},
#  {'dr_no': '230207571',
#   'date_rptd': '2023-03-16T00:00:00.000',
#   'date_occ': '2020-01-01T00:00:00.000',
#   'time_occ': '1500',
#   'area': '02',
#   'area_name': 'Rampart',
#   'rpt_dist_no': '0271',
#   'part_1_2': '2',
#   'crm_cd': '810',
#   'crm_cd_desc': 'SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W/ FRGN OBJ',
#   'mocodes': '2000 1251 1259 0522 0507 0913',
#   'vict_age': '13',
#   'vict_sex': 'F',
#   'vict_descent': 'H',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'status': 'JA',
#   'status_desc': 'Juv Arrest',
#   'crm_cd_1': '810',
#   'location': '900 S  LAKE                         ST',
#   'lat': '34.0539',
#   'lon': '-118.2799'},
#  {'dr_no': '230312288',
#   'date_rptd': '2023-06-01T00:00:00.000',
#   'date_occ': '2020-02-02T00:00:00.000',
#   'time_occ': '0315',
#   'area': '03',
#   'area_name': 'Southwest',
#   'rpt_dist_no': '0391',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0100 0928 0929 0935 1822',
#   'vict_age': '56',
#   'vict_sex': 'M',
#   'vict_descent': 'B',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '4200    SANTO TOMAS                  DR',
#   'lat': '34.0103',
#   'lon': '-118.3456'},
#  {'dr_no': '231805781',
#   'date_rptd': '2023-02-03T00:00:00.000',
#   'date_occ': '2020-07-01T00:00:00.000',
#   'time_occ': '0805',
#   'area': '18',
#   'area_name': 'Southeast',
#   'rpt_dist_no': '1802',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0928 1822',
#   'vict_age': '22',
#   'vict_sex': 'F',
#   'vict_descent': 'B',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '400 W  90TH                         ST',
#   'lat': '33.9551',
#   'lon': '-118.2814'},
#  {'dr_no': '231322474',
#   'date_rptd': '2023-12-24T00:00:00.000',
#   'date_occ': '2020-01-09T00:00:00.000',
#   'time_occ': '1200',
#   'area': '13',
#   'area_name': 'Newton',
#   'rpt_dist_no': '1354',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0100',
#   'vict_age': '23',
#   'vict_sex': 'M',
#   'vict_descent': 'B',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '4000    WALL                         ST',
#   'lat': '34.0112',
#   'lon': '-118.2716'},
#  {'dr_no': '210705560',
#   'date_rptd': '2020-11-27T00:00:00.000',
#   'date_occ': '2020-11-27T00:00:00.000',
#   'time_occ': '1800',
#   'area': '07',
#   'area_name': 'Wilshire',
#   'rpt_dist_no': '0776',
#   'part_1_2': '1',
#   'crm_cd': '230',
#   'crm_cd_desc': 'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT',
#   'mocodes': '1309 0400',
#   'vict_age': '31',
#   'vict_sex': 'F',
#   'vict_descent': 'O',
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'weapon_used_cd': '307',
#   'weapon_desc': 'VEHICLE',
#   'status': 'AA',
#   'status_desc': 'Adult Arrest',
#   'crm_cd_1': '230',
#   'location': '4500    LOMITA                       ST',
#   'lat': '34.0452',
#   'lon': '-118.3351'},
#  {'dr_no': '221016258',
#   'date_rptd': '2022-09-20T00:00:00.000',
#   'date_occ': '2020-01-01T00:00:00.000',
#   'time_occ': '0001',
#   'area': '10',
#   'area_name': 'West Valley',
#   'rpt_dist_no': '1067',
#   'part_1_2': '2',
#   'crm_cd': '956',
#   'crm_cd_desc': 'LETTERS, LEWD  -  TELEPHONE CALLS, LEWD',
#   'mocodes': '2041 1906 1822',
#   'vict_age': '30',
#   'vict_sex': 'F',
#   'vict_descent': 'O',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '956',
#   'location': '5200    GENESTA                      AV',
#   'lat': '34.166',
#   'lon': '-118.5033'},
#  {'dr_no': '220705246',
#   'date_rptd': '2022-02-03T00:00:00.000',
#   'date_occ': '2020-02-11T00:00:00.000',
#   'time_occ': '1200',
#   'area': '07',
#   'area_name': 'Wilshire',
#   'rpt_dist_no': '0747',
#   'part_1_2': '1',
#   'crm_cd': '341',
#   'crm_cd_desc': 'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD',
#   'vict_age': '57',
#   'vict_sex': 'F',
#   'vict_descent': 'B',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '341',
#   'location': '800 S  TREMAINE                     AV',
#   'lat': '34.0608',
#   'lon': '-118.3359'},
#  {'dr_no': '230808643',
#   'date_rptd': '2023-04-25T00:00:00.000',
#   'date_occ': '2020-01-01T00:00:00.000',
#   'time_occ': '0800',
#   'area': '08',
#   'area_name': 'West LA',
#   'rpt_dist_no': '0801',
#   'part_1_2': '1',
#   'crm_cd': '341',
#   'crm_cd_desc': 'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD',
#   'mocodes': '0352 1822 0344',
#   'vict_age': '56',
#   'vict_sex': 'F',
#   'vict_descent': 'W',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '341',
#   'location': '16700    MONTE HERMOSO                DR',
#   'lat': '34.0677',
#   'lon': '-118.552'},
#  {'dr_no': '231907172',
#   'date_rptd': '2023-03-21T00:00:00.000',
#   'date_occ': '2020-03-15T00:00:00.000',
#   'time_occ': '1200',
#   'area': '19',
#   'area_name': 'Mission',
#   'rpt_dist_no': '1983',
#   'part_1_2': '2',
#   'crm_cd': '812',
#   'crm_cd_desc': 'CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 YRS OLDER)',
#   'mocodes': '1259 0913 1817 1801 0503',
#   'vict_age': '12',
#   'vict_sex': 'F',
#   'vict_descent': 'H',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'weapon_used_cd': '400',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'status': 'AO',
#   'status_desc': 'Adult Other',
#   'crm_cd_1': '812',
#   'crm_cd_2': '860',
#   'location': '8500    COLUMBUS                     AV',
#   'lat': '34.2246',
#   'lon': '-118.4654'},
#  {'dr_no': '232011098',
#   'date_rptd': '2023-06-04T00:00:00.000',
#   'date_occ': '2020-07-01T00:00:00.000',
#   'time_occ': '1200',
#   'area': '20',
#   'area_name': 'Olympic',
#   'rpt_dist_no': '2088',
#   'part_1_2': '2',
#   'crm_cd': '812',
#   'crm_cd_desc': 'CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 YRS OLDER)',
#   'mocodes': '1251 1258 0400 0522 0913 0551 2021',
#   'vict_age': '7',
#   'vict_sex': 'F',
#   'vict_descent': 'H',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'weapon_used_cd': '400',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '812',
#   'crm_cd_2': '860',
#   'location': '1700 S  WESTMORELAND                 AV',
#   'lat': '34.0433',
#   'lon': '-118.2892'},
#  {'dr_no': '200412582',
#   'date_rptd': '2020-09-09T00:00:00.000',
#   'date_occ': '2020-09-09T00:00:00.000',
#   'time_occ': '0630',
#   'area': '04',
#   'area_name': 'Hollenbeck',
#   'rpt_dist_no': '0413',
#   'part_1_2': '1',
#   'crm_cd': '510',
#   'crm_cd_desc': 'VEHICLE - STOLEN',
#   'vict_age': '0',
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '510',
#   'location': '200 E  AVENUE 28',
#   'lat': '34.082',
#   'lon': '-118.213'},
#  {'dr_no': '232112438',
#   'date_rptd': '2023-08-03T00:00:00.000',
#   'date_occ': '2020-07-01T00:00:00.000',
#   'time_occ': '1200',
#   'area': '21',
#   'area_name': 'Topanga',
#   'rpt_dist_no': '2157',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '1822 0929 0930',
#   'vict_age': '46',
#   'vict_sex': 'M',
#   'vict_descent': 'B',
#   'premis_cd': '751',
#   'premis_desc': 'WEBSITE',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '21000    VANOWEN                      ST',
#   'lat': '34.1938',
#   'lon': '-118.5906'},
#  {'dr_no': '221105176',
#   'date_rptd': '2022-02-02T00:00:00.000',
#   'date_occ': '2020-02-09T00:00:00.000',
#   'time_occ': '1200',
#   'area': '11',
#   'area_name': 'Northeast',
#   'rpt_dist_no': '1132',
#   'part_1_2': '2',
#   'crm_cd': '930',
#   'crm_cd_desc': 'CRIMINAL THREATS - NO WEAPON DISPLAYED',
#   'mocodes': '1912 0913',
#   'vict_age': '30',
#   'vict_sex': 'F',
#   'vict_descent': 'W',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'weapon_used_cd': '500',
#   'weapon_desc': 'UNKNOWN WEAPON/OTHER WEAPON',
#   'status': 'AO',
#   'status_desc': 'Adult Other',
#   'crm_cd_1': '930',
#   'location': '2800    WAVERLY                      DR',
#   'lat': '34.1084',
#   'lon': '-118.2639'},
#  {'dr_no': '222106031',
#   'date_rptd': '2022-02-23T00:00:00.000',
#   'date_occ': '2020-08-14T00:00:00.000',
#   'time_occ': '1300',
#   'area': '21',
#   'area_name': 'Topanga',
#   'rpt_dist_no': '2113',
#   'part_1_2': '2',
#   'crm_cd': '668',
#   'crm_cd_desc': 'EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)',
#   'vict_age': '0',
#   'premis_cd': '203',
#   'premis_desc': 'OTHER BUSINESS',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '668',
#   'location': '7700    SAUSALITO                    AV',
#   'lat': '34.2105',
#   'lon': '-118.6157'},
#  {'dr_no': '211209197',
#   'date_rptd': '2021-03-20T00:00:00.000',
#   'date_occ': '2020-07-01T00:00:00.000',
#   'time_occ': '1425',
#   'area': '12',
#   'area_name': '77th Street',
#   'rpt_dist_no': '1243',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0928',
#   'vict_age': '51',
#   'vict_sex': 'M',
#   'vict_descent': 'B',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '1600 W  67TH                         ST',
#   'lat': '33.9785',
#   'lon': '-118.3068'},
#  {'dr_no': '220808837',
#   'date_rptd': '2022-04-28T00:00:00.000',
#   'date_occ': '2020-03-30T00:00:00.000',
#   'time_occ': '1630',
#   'area': '08',
#   'area_name': 'West LA',
#   'rpt_dist_no': '0842',
#   'part_1_2': '2',
#   'crm_cd': '624',
#   'crm_cd_desc': 'BATTERY - SIMPLE ASSAULT',
#   'mocodes': '2000 1813 0913 0416',
#   'vict_age': '24',
#   'vict_sex': 'F',
#   'vict_descent': 'O',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'weapon_used_cd': '400',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '624',
#   'location': '1200 S  WESTGATE                     AV',
#   'lat': '34.0474',
#   'lon': '-118.4635'},
#  {'dr_no': '231207725',
#   'date_rptd': '2023-02-27T00:00:00.000',
#   'date_occ': '2020-01-27T00:00:00.000',
#   'time_occ': '0635',
#   'area': '12',
#   'area_name': '77th Street',
#   'rpt_dist_no': '1242',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0100 0917 1822',
#   'vict_age': '37',
#   'vict_sex': 'M',
#   'vict_descent': 'H',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '6200    4TH                          AV',
#   'lat': '33.9837',
#   'lon': '-118.3216'},
#  {'dr_no': '231205231',
#   'date_rptd': '2023-01-17T00:00:00.000',
#   'date_occ': '2020-01-01T00:00:00.000',
#   'time_occ': '1535',
#   'area': '12',
#   'area_name': '77th Street',
#   'rpt_dist_no': '1268',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0100 0928',
#   'vict_age': '27',
#   'vict_sex': 'M',
#   'vict_descent': 'H',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '100 E  85TH                         ST',
#   'lat': '33.961',
#   'lon': '-118.2739'},
#  {'dr_no': '231108757',
#   'date_rptd': '2023-05-09T00:00:00.000',
#   'date_occ': '2020-05-08T00:00:00.000',
#   'time_occ': '2023',
#   'area': '11',
#   'area_name': 'Northeast',
#   'rpt_dist_no': '1101',
#   'part_1_2': '1',
#   'crm_cd': '330',
#   'crm_cd_desc': 'BURGLARY FROM VEHICLE',
#   'mocodes': '0344 1302 1307',
#   'vict_age': '20',
#   'vict_sex': 'M',
#   'vict_descent': 'A',
#   'premis_cd': '108',
#   'premis_desc': 'PARKING LOT',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '330',
#   'location': '2800 E  OBSERVATORY                  RD',
#   'lat': '34.1192',
#   'lon': '-118.3004'},
#  {'dr_no': '221404806',
#   'date_rptd': '2022-01-19T00:00:00.000',
#   'date_occ': '2020-01-18T00:00:00.000',
#   'time_occ': '1600',
#   'area': '14',
#   'area_name': 'Pacific',
#   'rpt_dist_no': '1446',
#   'part_1_2': '1',
#   'crm_cd': '420',
#   'crm_cd_desc': 'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)',
#   'vict_age': '0',
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '420',
#   'location': 'WASHINGTON                   PL',
#   'cross_street': 'INGLEWOOD',
#   'lat': '34.0022',
#   'lon': '-118.4255'},
#  {'dr_no': '220215983',
#   'date_rptd': '2022-09-06T00:00:00.000',
#   'date_occ': '2020-05-26T00:00:00.000',
#   'time_occ': '1200',
#   'area': '02',
#   'area_name': 'Rampart',
#   'rpt_dist_no': '0233',
#   'part_1_2': '1',
#   'crm_cd': '420',
#   'crm_cd_desc': 'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)',
#   'vict_age': '0',
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '420',
#   'location': '200 S  CORONADO                     ST',
#   'lat': '34.0697',
#   'lon': '-118.2779'},
#  {'dr_no': '211220472',
#   'date_rptd': '2021-09-27T00:00:00.000',
#   'date_occ': '2020-11-26T00:00:00.000',
#   'time_occ': '2000',
#   'area': '12',
#   'area_name': '77th Street',
#   'rpt_dist_no': '1259',
#   'part_1_2': '2',
#   'crm_cd': '930',
#   'crm_cd_desc': 'CRIMINAL THREATS - NO WEAPON DISPLAYED',
#   'mocodes': '0913 0400 0443 1814 2000',
#   'vict_age': '29',
#   'vict_sex': 'F',
#   'vict_descent': 'H',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'weapon_used_cd': '511',
#   'weapon_desc': 'VERBAL THREAT',
#   'status': 'AO',
#   'status_desc': 'Adult Other',
#   'crm_cd_1': '930',
#   'location': '7800 S  SAN PEDRO                    ST',
#   'lat': '33.9679',
#   'lon': '-118.2695'},
#  {'dr_no': '211818877',
#   'date_rptd': '2021-10-22T00:00:00.000',
#   'date_occ': '2020-03-10T00:00:00.000',
#   'time_occ': '1500',
#   'area': '18',
#   'area_name': 'Southeast',
#   'rpt_dist_no': '1801',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0100 1822 0930 0922',
#   'vict_age': '26',
#   'vict_sex': 'M',
#   'vict_descent': 'B',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '8700    ORCHARD                      AV',
#   'lat': '33.9587',
#   'lon': '-118.2882'},
#  {'dr_no': '221515929',
#   'date_rptd': '2022-10-10T00:00:00.000',
#   'date_occ': '2020-04-01T00:00:00.000',
#   'time_occ': '1200',
#   'area': '15',
#   'area_name': 'N Hollywood',
#   'rpt_dist_no': '1539',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0377',
#   'vict_age': '33',
#   'vict_sex': 'M',
#   'vict_descent': 'W',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '5700    CARTWRIGHT                   AV',
#   'lat': '34.174',
#   'lon': '-118.3638'},
#  {'dr_no': '230406865',
#   'date_rptd': '2023-03-28T00:00:00.000',
#   'date_occ': '2020-06-28T00:00:00.000',
#   'time_occ': '1250',
#   'area': '04',
#   'area_name': 'Hollenbeck',
#   'rpt_dist_no': '0478',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0100',
#   'vict_age': '34',
#   'vict_sex': 'F',
#   'vict_descent': 'B',
#   'premis_cd': '504',
#   'premis_desc': 'OTHER RESIDENCE',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '3400    PERCY                        ST',
#   'lat': '34.0286',
#   'lon': '-118.1996'},
#  {'dr_no': '231915767',
#   'date_rptd': '2023-10-25T00:00:00.000',
#   'date_occ': '2020-09-02T00:00:00.000',
#   'time_occ': '0001',
#   'area': '19',
#   'area_name': 'Mission',
#   'rpt_dist_no': '1985',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0917',
#   'vict_age': '15',
#   'vict_sex': 'F',
#   'vict_descent': 'H',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '8700    TOBIAS                       AV',
#   'lat': '34.228',
#   'lon': '-118.4517'},
#  {'dr_no': '221016530',
#   'date_rptd': '2022-11-15T00:00:00.000',
#   'date_occ': '2020-10-23T00:00:00.000',
#   'time_occ': '1735',
#   'area': '10',
#   'area_name': 'West Valley',
#   'rpt_dist_no': '1045',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '1822 0935 1202',
#   'vict_age': '65',
#   'vict_sex': 'M',
#   'vict_descent': 'W',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '17900    EMELITA                      ST',
#   'lat': '34.1776',
#   'lon': '-118.523'},
#  {'dr_no': '231210407',
#   'date_rptd': '2023-04-18T00:00:00.000',
#   'date_occ': '2020-01-01T00:00:00.000',
#   'time_occ': '0001',
#   'area': '12',
#   'area_name': '77th Street',
#   'rpt_dist_no': '1259',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0930 0929 0928 1822',
#   'vict_age': '59',
#   'vict_sex': 'F',
#   'vict_descent': 'W',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '700 E  73RD                         ST',
#   'lat': '33.9739',
#   'lon': '-118.263'},
#  {'dr_no': '220208037',
#   'date_rptd': '2022-03-30T00:00:00.000',
#   'date_occ': '2020-01-01T00:00:00.000',
#   'time_occ': '0800',
#   'area': '02',
#   'area_name': 'Rampart',
#   'rpt_dist_no': '0249',
#   'part_1_2': '2',
#   'crm_cd': '813',
#   'crm_cd_desc': 'CHILD ANNOYING (17YRS & UNDER)',
#   'mocodes': '1822 0359 1251 1259',
#   'vict_age': '15',
#   'vict_sex': 'F',
#   'vict_descent': 'H',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '813',
#   'location': '1100 W  6TH                          ST',
#   'lat': '34.0541',
#   'lon': '-118.2621'},
#  {'dr_no': '221504294',
#   'date_rptd': '2022-01-06T00:00:00.000',
#   'date_occ': '2020-10-30T00:00:00.000',
#   'time_occ': '0001',
#   'area': '15',
#   'area_name': 'N Hollywood',
#   'rpt_dist_no': '1535',
#   'part_1_2': '2',
#   'crm_cd': '812',
#   'crm_cd_desc': 'CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 YRS OLDER)',
#   'mocodes': '0522 0500 1258',
#   'vict_age': '9',
#   'vict_sex': 'M',
#   'vict_descent': 'W',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'weapon_used_cd': '500',
#   'weapon_desc': 'UNKNOWN WEAPON/OTHER WEAPON',
#   'status': 'AA',
#   'status_desc': 'Adult Arrest',
#   'crm_cd_1': '812',
#   'location': '5700    COLFAX                       AV',
#   'lat': '34.174',
#   'lon': '-118.3878'},
#  {'dr_no': '221312369',
#   'date_rptd': '2022-06-03T00:00:00.000',
#   'date_occ': '2020-12-10T00:00:00.000',
#   'time_occ': '0700',
#   'area': '13',
#   'area_name': 'Newton',
#   'rpt_dist_no': '1333',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0100',
#   'vict_age': '33',
#   'vict_sex': 'M',
#   'vict_descent': 'H',
#   'premis_cd': '750',
#   'premis_desc': 'CYBERSPACE',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '2700 S  CENTRAL                      AV',
#   'lat': '34.0174',
#   'lon': '-118.2621'},
#  {'dr_no': '220911866',
#   'date_rptd': '2022-07-26T00:00:00.000',
#   'date_occ': '2020-02-01T00:00:00.000',
#   'time_occ': '0505',
#   'area': '09',
#   'area_name': 'Van Nuys',
#   'rpt_dist_no': '0971',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0922 0929 0923 0930',
#   'vict_age': '34',
#   'vict_sex': 'F',
#   'vict_descent': 'W',
#   'premis_cd': '605',
#   'premis_desc': 'AUTOMATED TELLER MACHINE (ATM)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '15200    LA MAIDA                     ST',
#   'lat': '34.1585',
#   'lon': '-118.464'},
#  {'dr_no': '231906599',
#   'date_rptd': '2023-03-03T00:00:00.000',
#   'date_occ': '2020-01-14T00:00:00.000',
#   'time_occ': '1335',
#   'area': '19',
#   'area_name': 'Mission',
#   'rpt_dist_no': '1902',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0928',
#   'vict_age': '35',
#   'vict_sex': 'M',
#   'vict_descent': 'O',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '14500    WILLOWGREEN                  LN',
#   'lat': '34.3194',
#   'lon': '-118.4518'},
#  {'dr_no': '230610629',
#   'date_rptd': '2023-06-02T00:00:00.000',
#   'date_occ': '2020-05-31T00:00:00.000',
#   'time_occ': '0430',
#   'area': '06',
#   'area_name': 'Hollywood',
#   'rpt_dist_no': '0645',
#   'part_1_2': '1',
#   'crm_cd': '310',
#   'crm_cd_desc': 'BURGLARY',
#   'mocodes': '1822 1607 0216 0344',
#   'vict_age': '-2',
#   'vict_sex': 'X',
#   'vict_descent': 'X',
#   'premis_cd': '203',
#   'premis_desc': 'OTHER BUSINESS',
#   'weapon_used_cd': '500',
#   'weapon_desc': 'UNKNOWN WEAPON/OTHER WEAPON',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '310',
#   'location': '1700    ORCHID                       AV',
#   'lat': '34.103',
#   'lon': '-118.3402'},
#  {'dr_no': '220321807',
#   'date_rptd': '2022-12-13T00:00:00.000',
#   'date_occ': '2020-05-17T00:00:00.000',
#   'time_occ': '1620',
#   'area': '03',
#   'area_name': 'Southwest',
#   'rpt_dist_no': '0317',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0929 1822 0100 0930 0922',
#   'vict_age': '50',
#   'vict_sex': 'M',
#   'vict_descent': 'B',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '1400 W  25TH                         ST',
#   'lat': '34.0337',
#   'lon': '-118.2915'},
#  {'dr_no': '221216052',
#   'date_rptd': '2022-07-07T00:00:00.000',
#   'date_occ': '2020-02-23T00:00:00.000',
#   'time_occ': '1000',
#   'area': '12',
#   'area_name': '77th Street',
#   'rpt_dist_no': '1256',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0100',
#   'vict_age': '28',
#   'vict_sex': 'F',
#   'vict_descent': 'B',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '500 W  75TH                         ST',
#   'lat': '33.9717',
#   'lon': '-118.2827'},
#  {'dr_no': '241504067',
#   'date_rptd': '2024-01-02T00:00:00.000',
#   'date_occ': '2020-12-29T00:00:00.000',
#   'time_occ': '0750',
#   'area': '15',
#   'area_name': 'N Hollywood',
#   'rpt_dist_no': '1555',
#   'part_1_2': '2',
#   'crm_cd': '903',
#   'crm_cd_desc': 'CONTEMPT OF COURT',
#   'mocodes': '0913 2038',
#   'vict_age': '37',
#   'vict_sex': 'M',
#   'vict_descent': 'W',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '903',
#   'location': '5000    TUJUNGA                      AV',
#   'lat': '34.1614',
#   'lon': '-118.379'},
#  {'dr_no': '220508440',
#   'date_rptd': '2022-04-27T00:00:00.000',
#   'date_occ': '2020-07-07T00:00:00.000',
#   'time_occ': '1200',
#   'area': '05',
#   'area_name': 'Harbor',
#   'rpt_dist_no': '0585',
#   'part_1_2': '1',
#   'crm_cd': '341',
#   'crm_cd_desc': 'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD',
#   'mocodes': '0344 1202 1606',
#   'vict_age': '64',
#   'vict_sex': 'M',
#   'vict_descent': 'H',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '341',
#   'location': '2300 S  MEYLER                       ST',
#   'lat': '33.7234',
#   'lon': '-118.2968'},
#  {'dr_no': '220213256',
#   'date_rptd': '2022-07-14T00:00:00.000',
#   'date_occ': '2020-07-14T00:00:00.000',
#   'time_occ': '0900',
#   'area': '02',
#   'area_name': 'Rampart',
#   'rpt_dist_no': '0257',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0100 0928 1202',
#   'vict_age': '79',
#   'vict_sex': 'M',
#   'vict_descent': 'B',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '1200 W  7TH                          ST',
#   'lat': '34.0552',
#   'lon': '-118.2675'},
#  {'dr_no': '221607555',
#   'date_rptd': '2022-04-22T00:00:00.000',
#   'date_occ': '2020-08-01T00:00:00.000',
#   'time_occ': '1200',
#   'area': '16',
#   'area_name': 'Foothill',
#   'rpt_dist_no': '1612',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0928',
#   'vict_age': '40',
#   'vict_sex': 'F',
#   'vict_descent': 'H',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '11100    HERRICK                      AV',
#   'lat': '34.2713',
#   'lon': '-118.415'},
#  {'dr_no': '221516944',
#   'date_rptd': '2022-11-03T00:00:00.000',
#   'date_occ': '2020-06-01T00:00:00.000',
#   'time_occ': '1200',
#   'area': '15',
#   'area_name': 'N Hollywood',
#   'rpt_dist_no': '1517',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '1817',
#   'vict_age': '59',
#   'vict_sex': 'M',
#   'vict_descent': 'O',
#   'premis_cd': '203',
#   'premis_desc': 'OTHER BUSINESS',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '6700    BAKMAN                       AV',
#   'lat': '34.1925',
#   'lon': '-118.3779'},
#  {'dr_no': '230617817',
#   'date_rptd': '2023-11-14T00:00:00.000',
#   'date_occ': '2020-11-13T00:00:00.000',
#   'time_occ': '2015',
#   'area': '06',
#   'area_name': 'Hollywood',
#   'rpt_dist_no': '0622',
#   'part_1_2': '1',
#   'crm_cd': '420',
#   'crm_cd_desc': 'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)',
#   'vict_age': '0',
#   'premis_cd': '108',
#   'premis_desc': 'PARKING LOT',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '420',
#   'location': '7200    FRANKLIN                     AV',
#   'lat': '34.1146',
#   'lon': '-118.3607'},
#  {'dr_no': '231115685',
#   'date_rptd': '2023-11-12T00:00:00.000',
#   'date_occ': '2020-11-12T00:00:00.000',
#   'time_occ': '1430',
#   'area': '11',
#   'area_name': 'Northeast',
#   'rpt_dist_no': '1123',
#   'part_1_2': '1',
#   'crm_cd': '440',
#   'crm_cd_desc': 'THEFT PLAIN - PETTY ($950 & UNDER)',
#   'mocodes': '0344',
#   'vict_age': '27',
#   'vict_sex': 'M',
#   'vict_descent': 'W',
#   'premis_cd': '108',
#   'premis_desc': 'PARKING LOT',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '440',
#   'location': '3300    GLENDALE                     BL',
#   'lat': '34.1142',
#   'lon': '-118.2652'},
#  {'dr_no': '231707687',
#   'date_rptd': '2023-04-04T00:00:00.000',
#   'date_occ': '2020-05-08T00:00:00.000',
#   'time_occ': '1845',
#   'area': '17',
#   'area_name': 'Devonshire',
#   'rpt_dist_no': '1745',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0917 0929',
#   'vict_age': '44',
#   'vict_sex': 'M',
#   'vict_descent': 'O',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '17100    CHATSWORTH                   ST',
#   'lat': '34.2648',
#   'lon': '-118.5055'},
#  {'dr_no': '230711357',
#   'date_rptd': '2023-06-26T00:00:00.000',
#   'date_occ': '2020-01-01T00:00:00.000',
#   'time_occ': '0001',
#   'area': '07',
#   'area_name': 'Wilshire',
#   'rpt_dist_no': '0774',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '1501',
#   'vict_age': '32',
#   'vict_sex': 'F',
#   'vict_descent': 'H',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '4900 W  WASHINGTON                   BL',
#   'lat': '34.0431',
#   'lon': '-118.3482'},
#  {'dr_no': '220409258',
#   'date_rptd': '2022-05-29T00:00:00.000',
#   'date_occ': '2020-03-29T00:00:00.000',
#   'time_occ': '1315',
#   'area': '04',
#   'area_name': 'Hollenbeck',
#   'rpt_dist_no': '0467',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0100',
#   'vict_age': '16',
#   'vict_sex': 'M',
#   'vict_descent': 'H',
#   'premis_cd': '504',
#   'premis_desc': 'OTHER RESIDENCE',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '2600 E  4TH                          ST',
#   'lat': '34.0395',
#   'lon': '-118.2093'},
#  {'dr_no': '220119956',
#   'date_rptd': '2022-09-06T00:00:00.000',
#   'date_occ': '2020-07-01T00:00:00.000',
#   'time_occ': '1130',
#   'area': '01',
#   'area_name': 'Central',
#   'rpt_dist_no': '0162',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0928 1822',
#   'vict_age': '22',
#   'vict_sex': 'F',
#   'vict_descent': 'B',
#   'premis_cd': '750',
#   'premis_desc': 'CYBERSPACE',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '800 S  HOPE                         ST',
#   'lat': '34.0466',
#   'lon': '-118.259'},
#  {'dr_no': '240604173',
#   'date_rptd': '2024-01-05T00:00:00.000',
#   'date_occ': '2020-07-09T00:00:00.000',
#   'time_occ': '1230',
#   'area': '06',
#   'area_name': 'Hollywood',
#   'rpt_dist_no': '0637',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0928',
#   'vict_age': '21',
#   'vict_sex': 'M',
#   'vict_descent': 'W',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '6200    HOLLYWOOD                    BL',
#   'lat': '34.103',
#   'lon': '-118.3225'},
#  {'dr_no': '220104934',
#   'date_rptd': '2022-01-17T00:00:00.000',
#   'date_occ': '2020-12-20T00:00:00.000',
#   'time_occ': '1730',
#   'area': '01',
#   'area_name': 'Central',
#   'rpt_dist_no': '0158',
#   'part_1_2': '1',
#   'crm_cd': '341',
#   'crm_cd_desc': 'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD',
#   'mocodes': '1822 1414 0947 0344',
#   'vict_age': '0',
#   'vict_sex': 'X',
#   'vict_descent': 'X',
#   'premis_cd': '102',
#   'premis_desc': 'SIDEWALK',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '341',
#   'location': '6TH                          ST',
#   'cross_street': 'GLADYS                       AV',
#   'lat': '34.0403',
#   'lon': '-118.2421'},
#  {'dr_no': '230817493',
#   'date_rptd': '2023-11-27T00:00:00.000',
#   'date_occ': '2020-09-13T00:00:00.000',
#   'time_occ': '2100',
#   'area': '08',
#   'area_name': 'West LA',
#   'rpt_dist_no': '0829',
#   'part_1_2': '2',
#   'crm_cd': '626',
#   'crm_cd_desc': 'INTIMATE PARTNER - SIMPLE ASSAULT',
#   'mocodes': '1814 0913 0400',
#   'vict_age': '42',
#   'vict_sex': 'F',
#   'vict_descent': 'H',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'weapon_used_cd': '400',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '626',
#   'location': '1700    COMSTOCK                     AV',
#   'lat': '34.0596',
#   'lon': '-118.4233'},
#  {'dr_no': '221718084',
#   'date_rptd': '2022-12-20T00:00:00.000',
#   'date_occ': '2020-12-02T00:00:00.000',
#   'time_occ': '1510',
#   'area': '17',
#   'area_name': 'Devonshire',
#   'rpt_dist_no': '1764',
#   'part_1_2': '1',
#   'crm_cd': '440',
#   'crm_cd_desc': 'THEFT PLAIN - PETTY ($950 & UNDER)',
#   'mocodes': '0344',
#   'vict_age': '15',
#   'vict_sex': 'F',
#   'vict_descent': 'H',
#   'premis_cd': '404',
#   'premis_desc': 'DEPARTMENT STORE',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '440',
#   'location': '9300    TAMPA                        AV',
#   'lat': '34.244',
#   'lon': '-118.5583'},
#  {'dr_no': '221110929',
#   'date_rptd': '2022-06-28T00:00:00.000',
#   'date_occ': '2020-06-27T00:00:00.000',
#   'time_occ': '1945',
#   'area': '11',
#   'area_name': 'Northeast',
#   'rpt_dist_no': '1113',
#   'part_1_2': '1',
#   'crm_cd': '330',
#   'crm_cd_desc': 'BURGLARY FROM VEHICLE',
#   'mocodes': '0344',
#   'vict_age': '34',
#   'vict_sex': 'F',
#   'vict_descent': 'W',
#   'premis_cd': '108',
#   'premis_desc': 'PARKING LOT',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '330',
#   'location': '2800    COLORADO                     BL',
#   'lat': '34.1428',
#   'lon': '-118.2261'},
#  {'dr_no': '231711735',
#   'date_rptd': '2023-06-07T00:00:00.000',
#   'date_occ': '2020-09-02T00:00:00.000',
#   'time_occ': '0800',
#   'area': '17',
#   'area_name': 'Devonshire',
#   'rpt_dist_no': '1775',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0929 1822',
#   'vict_age': '46',
#   'vict_sex': 'F',
#   'vict_descent': 'H',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '17400    NORDHOFF                     ST',
#   'lat': '34.2394',
#   'lon': '-118.5112'},
#  {'dr_no': '231912127',
#   'date_rptd': '2023-07-26T00:00:00.000',
#   'date_occ': '2020-01-26T00:00:00.000',
#   'time_occ': '1735',
#   'area': '19',
#   'area_name': 'Mission',
#   'rpt_dist_no': '1913',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0923',
#   'vict_age': '46',
#   'vict_sex': 'F',
#   'vict_descent': 'H',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '14600    NURMI                        ST',
#   'lat': '34.307',
#   'lon': '-118.4521'},
#  {'dr_no': '231818830',
#   'date_rptd': '2023-11-01T00:00:00.000',
#   'date_occ': '2020-01-01T00:00:00.000',
#   'time_occ': '0001',
#   'area': '18',
#   'area_name': 'Southeast',
#   'rpt_dist_no': '1841',
#   'part_1_2': '2',
#   'crm_cd': '762',
#   'crm_cd_desc': 'LEWD CONDUCT',
#   'mocodes': '0913 0602 0360 0545 0536 0531 1258',
#   'vict_age': '6',
#   'vict_sex': 'M',
#   'vict_descent': 'B',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '762',
#   'location': '500 W  108TH                        ST',
#   'lat': '33.9383',
#   'lon': '-118.2826'},
#  {'dr_no': '221710268',
#   'date_rptd': '2022-06-21T00:00:00.000',
#   'date_occ': '2020-05-20T00:00:00.000',
#   'time_occ': '0600',
#   'area': '17',
#   'area_name': 'Devonshire',
#   'rpt_dist_no': '1767',
#   'part_1_2': '1',
#   'crm_cd': '441',
#   'crm_cd_desc': 'THEFT PLAIN - ATTEMPT',
#   'mocodes': '0352 0344 1202 2004 2021 0913 1817',
#   'vict_age': '72',
#   'vict_sex': 'F',
#   'vict_descent': 'H',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '441',
#   'location': '18600    PRAIRIE                      ST',
#   'lat': '34.2442',
#   'lon': '-118.5362'},
#  {'dr_no': '231007464',
#   'date_rptd': '2023-03-30T00:00:00.000',
#   'date_occ': '2020-06-25T00:00:00.000',
#   'time_occ': '1225',
#   'area': '10',
#   'area_name': 'West Valley',
#   'rpt_dist_no': '1015',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '1822 0929',
#   'vict_age': '28',
#   'vict_sex': 'F',
#   'vict_descent': 'H',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '7400    JAMIESON                     AV',
#   'lat': '34.2048',
#   'lon': '-118.5219'},
#  {'dr_no': '221917823',
#   'date_rptd': '2022-12-12T00:00:00.000',
#   'date_occ': '2020-04-05T00:00:00.000',
#   'time_occ': '1550',
#   'area': '19',
#   'area_name': 'Mission',
#   'rpt_dist_no': '1921',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'vict_age': '23',
#   'vict_sex': 'M',
#   'vict_descent': 'B',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '15400    EL CAJON                     ST',
#   'lat': '34.3054',
#   'lon': '-118.4681'},
#  {'dr_no': '211404152',
#   'date_rptd': '2021-01-04T00:00:00.000',
#   'date_occ': '2020-12-28T00:00:00.000',
#   'time_occ': '1600',
#   'area': '14',
#   'area_name': 'Pacific',
#   'rpt_dist_no': '1463',
#   'part_1_2': '1',
#   'crm_cd': '310',
#   'crm_cd_desc': 'BURGLARY',
#   'mocodes': '0397 0344',
#   'vict_age': '44',
#   'vict_sex': 'F',
#   'vict_descent': 'H',
#   'premis_cd': '221',
#   'premis_desc': 'PUBLIC STORAGE',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '310',
#   'location': '12600 W  JEFFERSON                    BL',
#   'lat': '33.9788',
#   'lon': '-118.4151'},
#  {'dr_no': '231205374',
#   'date_rptd': '2023-01-25T00:00:00.000',
#   'date_occ': '2020-10-12T00:00:00.000',
#   'time_occ': '1200',
#   'area': '12',
#   'area_name': '77th Street',
#   'rpt_dist_no': '1263',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0100 0930 1822',
#   'vict_age': '35',
#   'vict_sex': 'M',
#   'vict_descent': 'B',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '8300 S  HARVARD                      BL',
#   'lat': '33.9636',
#   'lon': '-118.3068'},
#  {'dr_no': '231505589',
#   'date_rptd': '2023-02-08T00:00:00.000',
#   'date_occ': '2020-09-01T00:00:00.000',
#   'time_occ': '1200',
#   'area': '15',
#   'area_name': 'N Hollywood',
#   'rpt_dist_no': '1557',
#   'part_1_2': '2',
#   'crm_cd': '812',
#   'crm_cd_desc': 'CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 YRS OLDER)',
#   'mocodes': '0400 0416',
#   'vict_age': '10',
#   'vict_sex': 'F',
#   'vict_descent': 'W',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'weapon_used_cd': '400',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '812',
#   'crm_cd_2': '860',
#   'location': '10800    HORTENSE                     ST',
#   'lat': '34.1548',
#   'lon': '-118.3662'},
#  {'dr_no': '231420506',
#   'date_rptd': '2023-11-06T00:00:00.000',
#   'date_occ': '2020-04-02T00:00:00.000',
#   'time_occ': '1825',
#   'area': '14',
#   'area_name': 'Pacific',
#   'rpt_dist_no': '1445',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0928',
#   'vict_age': '60',
#   'vict_sex': 'F',
#   'vict_descent': 'B',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '12700    PACIFIC                      AV',
#   'lat': '33.9993',
#   'lon': '-118.4397'},
#  {'dr_no': '221508505',
#   'date_rptd': '2022-04-20T00:00:00.000',
#   'date_occ': '2020-12-31T00:00:00.000',
#   'time_occ': '1200',
#   'area': '15',
#   'area_name': 'N Hollywood',
#   'rpt_dist_no': '1525',
#   'part_1_2': '1',
#   'crm_cd': '420',
#   'crm_cd_desc': 'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)',
#   'vict_age': '0',
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '420',
#   'location': '5900    CARPENTER                    AV',
#   'lat': '34.1776',
#   'lon': '-118.3889'},
#  {'dr_no': '231817823',
#   'date_rptd': '2023-10-13T00:00:00.000',
#   'date_occ': '2020-08-23T00:00:00.000',
#   'time_occ': '0001',
# ...
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '12300    BURBANK                      BL',
#   'lat': '34.1797',
#   'lon': '-118.4014'},
#  {'dr_no': '210604151',
#   'date_rptd': '2021-01-05T00:00:00.000',
#   'date_occ': '2020-12-31T00:00:00.000',
#   'time_occ': '1620',
#   'area': '06',
#   'area_name': 'Hollywood',
#   'rpt_dist_no': '0668',
#   'part_1_2': '1',
#   'crm_cd': '442',
#   'crm_cd_desc': 'SHOPLIFTING - PETTY THEFT ($950 & UNDER)',
#   'mocodes': '1822 0325 0601 0104 0209',
#   'vict_age': '0',
#   'vict_sex': 'X',
#   'vict_descent': 'X',
#   'premis_cd': '404',
#   'premis_desc': 'DEPARTMENT STORE',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '442',
#   'location': '5500 W  SUNSET                       BL',
#   'lat': '34.0981',
#   'lon': '-118.3103'},
#  {'dr_no': '232017258',
#   'date_rptd': '2023-10-16T00:00:00.000',
#   'date_occ': '2020-01-28T00:00:00.000',
#   'time_occ': '1305',
#   'area': '20',
#   'area_name': 'Olympic',
#   'rpt_dist_no': '2046',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '1822 0100 0344 0930 0928',
#   'vict_age': '32',
#   'vict_sex': 'M',
#   'vict_descent': 'W',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '800 S  BERENDO                      ST',
#   'lat': '34.0577',
#   'lon': '-118.2941'},
#  {'dr_no': '230109313',
#   'date_rptd': '2023-03-25T00:00:00.000',
#   'date_occ': '2020-02-25T00:00:00.000',
#   'time_occ': '1045',
#   'area': '01',
#   'area_name': 'Central',
#   'rpt_dist_no': '0162',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '1822 0928',
#   'vict_age': '27',
#   'vict_sex': 'M',
#   'vict_descent': 'O',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '800 S  HOPE                         ST',
#   'lat': '34.0466',
#   'lon': '-118.259'},
#  {'dr_no': '221504303',
#   'date_rptd': '2022-01-09T00:00:00.000',
#   'date_occ': '2020-12-01T00:00:00.000',
#   'time_occ': '2300',
#   'area': '15',
#   'area_name': 'N Hollywood',
#   'rpt_dist_no': '1539',
#   'part_1_2': '1',
#   'crm_cd': '821',
#   'crm_cd_desc': 'SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO ANUS OTH',
#   'mocodes': '0519 0545 0913 0554 2002 1206',
#   'vict_age': '24',
#   'vict_sex': 'M',
#   'vict_descent': 'H',
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'weapon_used_cd': '400',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '821',
#   'location': '10900    BURBANK                      BL',
#   'lat': '34.1758',
#   'lon': '-118.3643'},
#  {'dr_no': '230808592',
#   'date_rptd': '2023-04-03T00:00:00.000',
#   'date_occ': '2020-10-12T00:00:00.000',
#   'time_occ': '1340',
#   'area': '08',
#   'area_name': 'West LA',
#   'rpt_dist_no': '0806',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0935',
#   'vict_age': '55',
#   'vict_sex': 'F',
#   'vict_descent': 'W',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '900    BEL AIR                      RD',
#   'lat': '34.0894',
#   'lon': '-118.4418'},
#  {'dr_no': '240304549',
#   'date_rptd': '2024-01-11T00:00:00.000',
#   'date_occ': '2020-06-10T00:00:00.000',
#   'time_occ': '1655',
#   'area': '03',
#   'area_name': 'Southwest',
#   'rpt_dist_no': '0314',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0100 0928 1822 0930',
#   'vict_age': '34',
#   'vict_sex': 'F',
#   'vict_descent': 'B',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '3800 W  MONT CLAIR                   ST',
#   'lat': '34.0328',
#   'lon': '-118.323'},
#  {'dr_no': '231107472',
#   'date_rptd': '2023-04-04T00:00:00.000',
#   'date_occ': '2020-07-15T00:00:00.000',
#   'time_occ': '1445',
#   'area': '11',
#   'area_name': 'Northeast',
#   'rpt_dist_no': '1169',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '1822 0100 0922',
#   'vict_age': '17',
#   'vict_sex': 'F',
#   'vict_descent': 'B',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '5000    ECHO                         ST',
#   'lat': '34.1039',
#   'lon': '-118.2014'},
#  {'dr_no': '220910836',
#   'date_rptd': '2022-06-27T00:00:00.000',
#   'date_occ': '2020-06-25T00:00:00.000',
#   'time_occ': '2000',
#   'area': '09',
#   'area_name': 'Van Nuys',
#   'rpt_dist_no': '0926',
#   'part_1_2': '2',
#   'crm_cd': '740',
#   'crm_cd_desc': 'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)',
#   'mocodes': '0329 1822',
#   'vict_age': '24',
#   'vict_sex': 'F',
#   'vict_descent': 'B',
#   'premis_cd': '122',
#   'premis_desc': 'VEHICLE, PASSENGER/TRUCK',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '740',
#   'location': '14000    ARCHWOOD                     ST',
#   'lat': '34.193',
#   'lon': '-118.4378'},
#  {'dr_no': '230212110',
#   'date_rptd': '2023-06-08T00:00:00.000',
#   'date_occ': '2020-07-03T00:00:00.000',
#   'time_occ': '1300',
#   'area': '02',
#   'area_name': 'Rampart',
#   'rpt_dist_no': '0245',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0100 0922 0929 0930 0935 1822',
#   'vict_age': '24',
#   'vict_sex': 'M',
#   'vict_descent': 'B',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '500 S  GRAND VIEW                   ST',
#   'lat': '34.0613',
#   'lon': '-118.2765'},
#  {'dr_no': '221916217',
#   'date_rptd': '2022-10-28T00:00:00.000',
#   'date_occ': '2020-12-23T00:00:00.000',
#   'time_occ': '0001',
#   'area': '19',
#   'area_name': 'Mission',
#   'rpt_dist_no': '1912',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'vict_age': '58',
#   'vict_sex': 'M',
#   'vict_descent': 'H',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '13600    DE GARMO                     AV',
#   'lat': '34.3184',
#   'lon': '-118.467'},
#  {'dr_no': '220909185',
#   'date_rptd': '2022-05-15T00:00:00.000',
#   'date_occ': '2020-12-01T00:00:00.000',
#   'time_occ': '0001',
#   'area': '09',
#   'area_name': 'Van Nuys',
#   'rpt_dist_no': '0933',
#   'part_1_2': '2',
#   'crm_cd': '812',
#   'crm_cd_desc': 'CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 YRS OLDER)',
#   'mocodes': '1258 1251 0527 0913 1402',
#   'vict_age': '12',
#   'vict_sex': 'F',
#   'vict_descent': 'H',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'weapon_used_cd': '400',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'status': 'AA',
#   'status_desc': 'Adult Arrest',
#   'crm_cd_1': '812',
#   'crm_cd_2': '998',
#   'location': '14600    CALVERT                      ST',
#   'lat': '34.1817',
#   'lon': '-118.4509'},
#  {'dr_no': '201410297',
#   'date_rptd': '2020-05-01T00:00:00.000',
#   'date_occ': '2020-04-30T00:00:00.000',
#   'time_occ': '1900',
#   'area': '14',
#   'area_name': 'Pacific',
#   'rpt_dist_no': '1438',
#   'part_1_2': '1',
#   'crm_cd': '510',
#   'crm_cd_desc': 'VEHICLE - STOLEN',
#   'vict_age': '0',
#   'premis_cd': '101',
#   'premis_desc': 'STREET',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '510',
#   'location': '3700    GREENFIELD                   AV',
#   'lat': '34.0172',
#   'lon': '-118.4148'},
#  {'dr_no': '231420990',
#   'date_rptd': '2023-11-26T00:00:00.000',
#   'date_occ': '2020-12-28T00:00:00.000',
#   'time_occ': '2130',
#   'area': '14',
#   'area_name': 'Pacific',
#   'rpt_dist_no': '1435',
#   'part_1_2': '2',
#   'crm_cd': '626',
#   'crm_cd_desc': 'INTIMATE PARTNER - SIMPLE ASSAULT',
#   'mocodes': '0356 0400 0408 0429 1814',
#   'vict_age': '21',
#   'vict_sex': 'F',
#   'vict_descent': 'A',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'weapon_used_cd': '400',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '626',
#   'location': '11900    WESTMINSTER                  AV',
#   'lat': '34.0123',
#   'lon': '-118.4328'},
#  {'dr_no': '231204321',
#   'date_rptd': '2023-01-02T00:00:00.000',
#   'date_occ': '2020-07-02T00:00:00.000',
#   'time_occ': '1520',
#   'area': '12',
#   'area_name': '77th Street',
#   'rpt_dist_no': '1266',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0100 0930 0929 1822',
#   'vict_age': '27',
#   'vict_sex': 'F',
#   'vict_descent': 'B',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '400 W  80TH                         ST',
#   'lat': '33.9669',
#   'lon': '-118.2813'},
#  {'dr_no': '231717133',
#   'date_rptd': '2023-11-02T00:00:00.000',
#   'date_occ': '2020-12-02T00:00:00.000',
#   'time_occ': '0900',
#   'area': '17',
#   'area_name': 'Devonshire',
#   'rpt_dist_no': '1785',
#   'part_1_2': '1',
#   'crm_cd': '310',
#   'crm_cd_desc': 'BURGLARY',
#   'mocodes': '1605 0344 1501',
#   'vict_age': '51',
#   'vict_sex': 'F',
#   'vict_descent': 'H',
#   'premis_cd': '221',
#   'premis_desc': 'PUBLIC STORAGE',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '310',
#   'location': '18800    RAYEN                        ST',
#   'lat': '34.2319',
#   'lon': '-118.5425'},
#  {'dr_no': '232009763',
#   'date_rptd': '2023-04-21T00:00:00.000',
#   'date_occ': '2020-11-23T00:00:00.000',
#   'time_occ': '1700',
#   'area': '20',
#   'area_name': 'Olympic',
#   'rpt_dist_no': '2042',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0100 0922 0929 1822',
#   'vict_age': '68',
#   'vict_sex': 'M',
#   'vict_descent': 'K',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '3500    SAN MARINO                   ST',
#   'lat': '34.0564',
#   'lon': '-118.3131'},
#  {'dr_no': '231513372',
#   'date_rptd': '2023-08-10T00:00:00.000',
#   'date_occ': '2020-08-10T00:00:00.000',
#   'time_occ': '0135',
#   'area': '15',
#   'area_name': 'N Hollywood',
#   'rpt_dist_no': '1555',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0377',
#   'vict_age': '0',
#   'vict_sex': 'M',
#   'vict_descent': 'O',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '5000    LANKERSHIM                   BL',
#   'lat': '34.1611',
#   'lon': '-118.3723'},
#  {'dr_no': '221013527',
#   'date_rptd': '2022-09-02T00:00:00.000',
#   'date_occ': '2020-01-14T00:00:00.000',
#   'time_occ': '0200',
#   'area': '10',
#   'area_name': 'West Valley',
#   'rpt_dist_no': '1004',
#   'part_1_2': '2',
#   'crm_cd': '922',
#   'crm_cd_desc': 'CHILD STEALING',
#   'mocodes': '0913',
#   'vict_age': '44',
#   'vict_sex': 'M',
#   'vict_descent': 'O',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '922',
#   'location': '8100    ETIWANDA                     AV',
#   'lat': '34.2177',
#   'lon': '-118.5317'},
#  {'dr_no': '221609445',
#   'date_rptd': '2022-06-13T00:00:00.000',
#   'date_occ': '2020-01-01T00:00:00.000',
#   'time_occ': '1200',
#   'area': '16',
#   'area_name': 'Foothill',
#   'rpt_dist_no': '1664',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0344 0360',
#   'vict_age': '61',
#   'vict_sex': 'M',
#   'vict_descent': 'W',
#   'premis_cd': '203',
#   'premis_desc': 'OTHER BUSINESS',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '11600    SHELDON                      ST',
#   'lat': '34.2457',
#   'lon': '-118.385'},
#  {'dr_no': '222017127',
#   'date_rptd': '2022-11-14T00:00:00.000',
#   'date_occ': '2020-03-01T00:00:00.000',
#   'time_occ': '0700',
#   'area': '20',
#   'area_name': 'Olympic',
#   'rpt_dist_no': '2062',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0100 1822',
#   'vict_age': '53',
#   'vict_sex': 'F',
#   'vict_descent': 'A',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '3200 W  PICO                         BL',
#   'lat': '34.0506',
#   'lon': '-118.3127'},
#  {'dr_no': '220813395',
#   'date_rptd': '2022-08-17T00:00:00.000',
#   'date_occ': '2020-11-22T00:00:00.000',
#   'time_occ': '1300',
#   'area': '08',
#   'area_name': 'West LA',
#   'rpt_dist_no': '0841',
#   'part_1_2': '2',
#   'crm_cd': '649',
#   'crm_cd_desc': 'DOCUMENT FORGERY / STOLEN FELONY',
#   'mocodes': '0100 1202',
#   'vict_age': '63',
#   'vict_sex': 'F',
#   'vict_descent': 'W',
#   'premis_cd': '502',
#   'premis_desc': 'MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '649',
#   'location': '1200    BROCKTON                     AV',
#   'lat': '34.046',
#   'lon': '-118.4652'},
#  {'dr_no': '220609056',
#   'date_rptd': '2022-04-15T00:00:00.000',
#   'date_occ': '2020-04-04T00:00:00.000',
#   'time_occ': '1200',
#   'area': '06',
#   'area_name': 'Hollywood',
#   'rpt_dist_no': '0636',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0100 0344 0928',
#   'vict_age': '21',
#   'vict_sex': 'F',
#   'vict_descent': 'W',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '6300    HOLLYWOOD                    BL',
#   'lat': '34.1034',
#   'lon': '-118.3325'},
#  {'dr_no': '220309997',
#   'date_rptd': '2022-05-02T00:00:00.000',
#   'date_occ': '2020-11-01T00:00:00.000',
#   'time_occ': '1200',
#   'area': '03',
#   'area_name': 'Southwest',
#   'rpt_dist_no': '0393',
#   'part_1_2': '2',
#   'crm_cd': '627',
#   'crm_cd_desc': 'CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT',
#   'mocodes': '1251 1258 0416 0432 0552 0913',
#   'vict_age': '10',
#   'vict_sex': 'F',
#   'vict_descent': 'B',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'weapon_used_cd': '500',
#   'weapon_desc': 'UNKNOWN WEAPON/OTHER WEAPON',
#   'status': 'AA',
#   'status_desc': 'Adult Arrest',
#   'crm_cd_1': '627',
#   'location': '4100    LEIMERT                      BL',
#   'lat': '34.0098',
#   'lon': '-118.3242'},
#  {'dr_no': '231608256',
#   'date_rptd': '2023-05-15T00:00:00.000',
#   'date_occ': '2020-05-01T00:00:00.000',
#   'time_occ': '0001',
#   'area': '16',
#   'area_name': 'Foothill',
#   'rpt_dist_no': '1621',
#   'part_1_2': '2',
#   'crm_cd': '760',
#   'crm_cd_desc': 'LEWD/LASCIVIOUS ACTS WITH CHILD',
#   'mocodes': '0913 1259 0522 0500 0556',
#   'vict_age': '11',
#   'vict_sex': 'F',
#   'vict_descent': 'H',
#   'premis_cd': '501',
#   'premis_desc': 'SINGLE FAMILY DWELLING',
#   'weapon_used_cd': '400',
#   'weapon_desc': 'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)',
#   'status': 'AA',
#   'status_desc': 'Adult Arrest',
#   'crm_cd_1': '760',
#   'location': '10500    HADDON                       AV',
#   'lat': '34.2612',
#   'lon': '-118.4288'},
#  {'dr_no': '220214155',
#   'date_rptd': '2022-07-09T00:00:00.000',
#   'date_occ': '2020-09-01T00:00:00.000',
#   'time_occ': '0800',
#   'area': '02',
#   'area_name': 'Rampart',
#   'rpt_dist_no': '0269',
#   'part_1_2': '2',
#   'crm_cd': '354',
#   'crm_cd_desc': 'THEFT OF IDENTITY',
#   'mocodes': '0930 0377 0929',
#   'vict_age': '57',
#   'vict_sex': 'X',
#   'vict_descent': 'B',
#   'premis_cd': '750',
#   'premis_desc': 'CYBERSPACE',
#   'status': 'IC',
#   'status_desc': 'Invest Cont',
#   'crm_cd_1': '354',
#   'location': '700    WITMER                       ST',
#   'lat': '34.0524',
#   'lon': '-118.2678'},
#  ...]

# %%
response_df = pd.DataFrame(response)

# %%
response_df.head()
# Out:
#        dr_no                date_rptd                 date_occ time_occ area  \
# 0  190326475  2020-03-01T00:00:00.000  2020-03-01T00:00:00.000     2130   07
# 1  200106753  2020-02-09T00:00:00.000  2020-02-08T00:00:00.000     1800   01
# 2  200320258  2020-11-11T00:00:00.000  2020-11-04T00:00:00.000     1700   03
# 3  200907217  2023-05-10T00:00:00.000  2020-03-10T00:00:00.000     2037   09
# 4  220614831  2022-08-18T00:00:00.000  2020-08-17T00:00:00.000     1200   06
#
#    area_name rpt_dist_no part_1_2 crm_cd  \
# 0   Wilshire        0784        1    510
# 1    Central        0182        1    330
# 2  Southwest        0356        1    480
# 3   Van Nuys        0964        1    343
# 4  Hollywood        0666        2    354
#
#                                 crm_cd_desc  ... crm_cd_2  \
# 0                          VEHICLE - STOLEN  ...      998
# 1                     BURGLARY FROM VEHICLE  ...      998
# 2                             BIKE - STOLEN  ...      NaN
# 3  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)  ...      NaN
# 4                         THEFT OF IDENTITY  ...      NaN
#
#                                    location      lat        lon  \
# 0   1900 S  LONGWOOD                     AV  34.0375  -118.3506
# 1   1000 S  FLOWER                       ST  34.0444  -118.2628
# 2   1400 W  37TH                         ST   34.021  -118.3002
# 3  14000    RIVERSIDE                    DR  34.1576  -118.4387
# 4                         1900    TRANSIENT  34.0944  -118.3277
#
#                mocodes weapon_used_cd weapon_desc cross_street crm_cd_3  \
# 0                  NaN            NaN         NaN          NaN      NaN
# 1       1822 1402 0344            NaN         NaN          NaN      NaN
# 2            0344 1251            NaN         NaN          NaN      NaN
# 3            0325 1501            NaN         NaN          NaN      NaN
# 4  1822 1501 0930 2004            NaN         NaN          NaN      NaN
#
#   crm_cd_4
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
# [5 rows x 28 columns]

# %%
response_df["dr_no"].count()
# Out:
# 925720
